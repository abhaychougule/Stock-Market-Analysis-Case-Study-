# %%
import pandas as pd
amd=pd.read_csv('C:\\Study\\Full Open Pose\\Case Study 6\\AMD.csv')

# %%
#amd=pd.read_csv('AMD.csv',header=0,index_col='Date',parse_dates=True)

# %%
amd.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2003-12-31  15.20  15.20  14.81  14.90      14.90   7395900
# 1  2004-01-02  15.10  15.11  14.77  14.86      14.86   8220700
# 2  2004-01-05  15.05  15.27  15.01  15.20      15.20   9156000
# 3  2004-01-06  15.21  15.82  15.05  15.61      15.61  14592200
# 4  2004-01-07  15.78  15.99  15.49  15.66      15.66  15329300

# %%
amd.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 3947  2019-09-06  31.500000  31.510000  30.480000  30.559999  30.559999
# 3948  2019-09-09  30.930000  31.180000  30.240000  30.500000  30.500000
# 3949  2019-09-10  30.219999  30.379999  29.770000  30.230000  30.230000
# 3950  2019-09-11  30.379999  30.430000  29.510000  29.760000  29.760000
# 3951  2019-09-12  30.080000  30.840000  29.950001  30.209999  30.209999
#
#         Volume
# 3947  51673000
# 3948  54413200
# 3949  48604800
# 3950  50631700
# 3951  53618300

# %%
#using Pandas Data reader

# %%
import pandas_datareader as pdr

# %%
# Install Datareader in conda
#conda install -c anaconda pandas-datareader

# %%
import datetime

# %%
nvda=pdr.get_data_yahoo('NVDA',start=datetime.datetime(2004,1,1),end=datetime.datetime(2019,9,15))

# %%
qcom=pdr.get_data_yahoo('QCOM',start=datetime.datetime(2004,1,1),end=datetime.datetime(2019,9,15))

# %%
intc=pdr.get_data_yahoo('INTC',start=datetime.datetime(2004,1,1),end=datetime.datetime(2019,9,15))

# %%
ibm=pdr.get_data_yahoo('IBM',start=datetime.datetime(2004,1,1),end=datetime.datetime(2019,9,15))

# %%
type(nvda)
# Out:
# pandas.core.frame.DataFrame

# %%
ibm.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2004-01-02  93.050003  91.199997  92.860001  91.550003  5327800.0  61.160595
# 2004-01-05  93.089996  92.000000  92.000000  93.050003  5276300.0  62.162693
# 2004-01-06  93.190002  92.139999  92.199997  93.059998  4380000.0  62.169365
# 2004-01-07  93.379997  92.470001  93.139999  92.779999  4927600.0  61.982319
# 2004-01-08  93.209999  92.029999  93.209999  93.040001  6179800.0  62.156013

# %%
nvda.head(n=2)
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2004-01-02  7.963333  7.693333  7.856667  7.693333  10910400.0   7.085020
# 2004-01-05  7.996666  7.740000  7.810000  7.943333  14382300.0   7.315253

# %%
ibm.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3953.000000  3953.000000  3953.000000  3953.000000  3.953000e+03
# mean    138.699992   136.615249   137.605538   137.680572  5.651459e+06
# std      38.477135    38.202886    38.346329    38.342979  3.084929e+06
# min      73.690002    69.500000    72.529999    71.739998  1.027500e+06
# 25%     103.000000   100.209999   101.320000   101.650002  3.657000e+06
# 50%     141.020004   139.100006   139.990005   140.080002  4.853000e+06
# 75%     167.449997   165.100006   166.250000   166.250000  6.679400e+06
# max     215.899994   214.300003   215.380005   215.800003  3.077070e+07
#
#          Adj Close
# count  3953.000000
# mean    107.609125
# std      35.206611
# min      48.570713
# 25%      71.501549
# 50%     119.748489
# 75%     138.183701
# max     165.514679

# %%
nvda.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
nvda.index
# Out:
# DatetimeIndex(['2004-01-02', '2004-01-05', '2004-01-06', '2004-01-07',
#                '2004-01-08', '2004-01-09', '2004-01-12', '2004-01-13',
#                '2004-01-14', '2004-01-15',
#                ...
#                '2019-09-03', '2019-09-04', '2019-09-05', '2019-09-06',
#                '2019-09-09', '2019-09-10', '2019-09-11', '2019-09-12',
#                '2019-09-13', '2019-09-16'],
#               dtype='datetime64[ns]', name='Date', length=3953, freq=None)

# %%
nvda.shape
# Out:
# (3953, 6)

# %%
#time serties data
#we have data of evryday what happend in stock markrt
#its a movement of data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.dates as mdates

# %%
plt.plot(ibm.index,ibm['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#subplot
#sharex=True

f,ax=plt.subplots(2, 2, figsize=(10,10))
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
f.gca().xaxis.set_major_locator(mdates.YearLocator())


ax[0,0].plot(nvda.index,nvda['Adj Close'],color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');


ax[0,1].plot(qcom.index,qcom['Adj Close'],color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('QCOM');
             
ax[1,0].plot(intc.index,intc['Adj Close'],color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

             
ax[1,1].plot(ibm.index,ibm['Adj Close'],color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('IBM');
#ax[1,1].xaxis(rotation=90)

# %%
ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
plt.plot(ibm_18.index,ibm_18['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
ibm.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2004-01-02  93.050003  91.199997  92.860001  91.550003  5327800.0  61.160595
# 2004-01-05  93.089996  92.000000  92.000000  93.050003  5276300.0  62.162693
# 2004-01-06  93.190002  92.139999  92.199997  93.059998  4380000.0  62.169365
# 2004-01-07  93.379997  92.470001  93.139999  92.779999  4927600.0  61.982319
# 2004-01-08  93.209999  92.029999  93.209999  93.040001  6179800.0  62.156013

# %%
#Down Sampling of dataset

# %%
#subplot

f,ax=plt.subplots(2, 2, figsize=(10,10),sharex=True,sharey=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y'))
f.gca().xaxis.set_major_locator(mdates.MonthLocator())



#ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
#plt.plot(ibm_18.index,ibm_18['Adj Close'],'.',color='r')
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
#plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
#plt.grid(True)
#plt.xticks(rotation=90)
#plt.show()

ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[0,0].plot(ibm.index,ibm['Adj Close'],'.',color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('IBM');

nvda_18=nvda.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[0,1].plot(nvda.index,nvda['Adj Close'],'.',color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('NVDA');
             
intc_18=intc.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,0].plot(intc.index,intc['Adj Close'],'.',color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

qcom_18=qcom.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,1].plot(qcom.index,qcom['Adj Close'],'.',color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QCOM');

# %%
#Up Sampling data set

# %%
nvda_18.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02  199.500000  194.500000  195.779999  199.350006   8890400.0
# 2018-01-03  213.699997  203.750000  204.100006  212.470001  22867600.0
# 2018-01-04  218.050003  212.690002  215.759995  213.589996  14581700.0
# 2018-01-05  216.910004  211.080002  214.190002  215.399994  14503100.0
# 2018-01-08  225.000000  218.580002  220.399994  222.000000  22030400.0
#
#              Adj Close
# Date
# 2018-01-02  198.021957
# 2018-01-03  211.054535
# 2018-01-04  212.167068
# 2018-01-05  213.965012
# 2018-01-08  220.521042

# %%
monthly_nvda_18=nvda_18.resample('4M').mean()
plt.scatter(monthly_nvda_18.index,monthly_nvda_18['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
#subplot # Up Sampling

f,ax=plt.subplots(2, 2, figsize=(10,10),sharex=True,sharey=True)
#f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y'))
#f.gca().xaxis.set_major_locator(mdates.MonthLocator())



#ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
#plt.plot(ibm_18.index,ibm_18['Adj Close'],'.',color='r')
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
#plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
#plt.grid(True)
#plt.xticks(rotation=90)
#plt.show()
monthly_nvda_18=nvda_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[0,0].plot(monthly_nvda_18.index,monthly_nvda_18['Adj Close'],'.',color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVDA');

monthly_ibm_18=ibm_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[0,1].plot(monthly_ibm_18.index,monthly_ibm_18['Adj Close'],'.',color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('IBM');

monthly_qcom_18=qcom_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,0].plot(monthly_qcom_18.index,monthly_qcom_18['Adj Close'],'.',color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QCOM');

monthly_intc_18=intc_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,1].plot(monthly_intc_18.index,monthly_intc_18['Adj Close'],'.',color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('INTC');

# %%
monthly_nvda_18.head()
# Out:
#                   High         Low        Open       Close        Volume  \
# Date
# 2018-01-31  229.685239  223.649049  226.051905  227.539049  1.363835e+07
# 2018-05-31  241.846024  233.497952  238.000603  237.606747  1.570970e+07
# 2018-09-30  261.965596  255.896667  258.817024  259.205595  9.632575e+06
# 2019-01-31  197.242699  187.080475  193.221587  191.356666  1.650465e+07
#
#              Adj Close
# Date
# 2018-01-31  226.023197
# 2018-05-31  236.157244
# 2018-09-30  257.837002
# 2019-01-31  190.469922

# %% [markdown]
# # resampaling weekly

# %%
ibm_19=ibm.loc[pd.Timestamp('2019-1-15'):pd.Timestamp('2019-09-15')]

# %%
ibm_19=ibm.loc[pd.Timestamp('2019-1-15'):pd.Timestamp('2019-09-15')]
weekly_ibm_19=ibm_19.resample('w').mean()
weekly_ibm_19.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-01-20  122.765001  121.227501  121.592499  122.340002   4596750.0
# 2019-01-27  131.612503  128.927496  130.042500  130.477499  11036600.0
# 2019-02-03  135.034000  133.304004  134.162000  134.300003   4717140.0
# 2019-02-10  135.170001  133.478000  134.082001  134.792004   4374880.0
# 2019-02-17  137.012000  135.756003  136.221997  136.414001   3459760.0
#
#              Adj Close
# Date
# 2019-01-20  115.534363
# 2019-01-27  123.219175
# 2019-02-03  126.829041
# 2019-02-10  127.881017
# 2019-02-17  130.326419

# %%
plt.plot(weekly_ibm_19.index,weekly_ibm_19['Adj Close'],'-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## do subplot of sampling of weekly data

# %%
#making subset ploting

ibm_19=ibm.loc[pd.Timestamp('2019-1-15'):pd.Timestamp('2019-09-15')]
weekly_ibm_19=ibm_19.resample('w').mean()

nvda_19=nvda.loc[pd.Timestamp('2019-1-15'):pd.Timestamp('2019-09-15')]
weekly_nvda_19=nvda_19.resample('w').mean()

intc_19=intc.loc[pd.Timestamp('2019-1-15'):pd.Timestamp('2019-09-15')]
weekly_intc_19=intc_19.resample('w').mean()

qcom_19=qcom.loc[pd.Timestamp('2019-1-15'):pd.Timestamp('2019-09-15')]
weekly_qcom_19=qcom_19.resample('w').mean()


f,ax=plt.subplots(2,2,figsize=(10,10),sharex=True,sharey=True)



weekly_nvda_19=nvda_18.resample('4M').mean()

ax[0,0].plot(weekly_nvda_19.index,weekly_nvda_19['Adj Close'],'-o',color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVDA');

weekly_ibm_19=ibm_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[0,1].plot(weekly_ibm_19.index,weekly_ibm_19['Adj Close'],'-o',color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('IBM');

weekly_qcom_19=qcom_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,0].plot(weekly_qcom_19.index,weekly_qcom_19['Adj Close'],'-o',color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QCOM');

weekly_intc_19=intc_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,1].plot(weekly_intc_19.index,weekly_intc_19['Adj Close'],'-o',color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('INTC');

# %% [markdown]
# # What is the opening value and closing value also a diffence of the value

# %%
ibm['diff']=ibm['Open']-ibm['Close']
ibm_diff=ibm.resample('W').mean()
ibm_diff.tail(10)
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-07-21  146.647998  143.767999  144.426001  145.846002  6378680.0
# 2019-07-28  151.228000  149.198001  150.334003  150.380002  3358720.0
# 2019-08-04  151.565997  148.004001  149.747998  149.292004  4575360.0
# 2019-08-11  141.376001  137.595999  140.694000  139.366000  5724640.0
# 2019-08-18  134.712000  131.493997  133.526001  133.367996  4028460.0
# 2019-08-25  135.497998  132.826001  134.680005  133.236002  3300540.0
# 2019-09-01  133.530002  131.581998  132.489999  132.866000  3241580.0
# 2019-09-08  138.639996  136.747501  137.595005  137.990005  3166050.0
# 2019-09-15  144.457999  142.254004  143.358002  143.708002  3557600.0
# 2019-09-22  143.639999  142.270004  142.559998  142.479996  1928500.0
#
#              Adj Close      diff
# Date
# 2019-07-21  140.992636 -1.420001
# 2019-07-28  145.375760 -0.045999
# 2019-08-04  144.323962  0.455994
# 2019-08-11  135.357556  1.328000
# ...

# %%
plt.scatter(ibm_diff.loc['2019-01-01':'2019-09-15'].index,ibm_diff.loc['2019-01-01':'2019-09-15']['diff'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#this is for all companies with subset of grafh

ibm['diff']=ibm['Open']-ibm['Close']
ibm_diff=ibm.resample('W').mean()

intc['diff']=intc['Open']-intc['Close']
intc_diff=intc.resample('W').mean()

qcom['diff']=qcom['Open']-qcom['Close']
qcom_diff=qcom.resample('W').mean()

nvda['diff']=nvda['Open']-nvda['Close']
nvda_diff=nvda.resample('W').mean()


f,ax=plt.subplots(2,2,figsize=(10,10))
#sharex=True,sharey=True

#weekly_nvda_19=nvda_18.resample('4M').mean()

ax[0,0].scatter(nvda_diff.loc['2019-01-01':'2019-09-15'].index,nvda_diff.loc['2019-01-01':'2019-09-15']['diff'],color='y')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVDA');

#weekly_ibm_19=ibm_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[0,1].scatter(ibm_diff.loc['2019-01-01':'2019-09-15'].index,ibm_diff.loc['2019-01-01':'2019-09-15']['diff'],color='b')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('IBM');

#weekly_qcom_19=qcom_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,0].scatter(qcom_diff.loc['2019-01-01':'2019-09-15'].index,qcom_diff.loc['2019-01-01':'2019-09-15']['diff'],color='g')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QCOM');

#weekly_intc_19=intc_18.resample('4M').mean()
#monthly_ibm_18=ibm.loc[pd.Timestamp('2018-1-1'):pd.Timestamp('2018-12-31')]
ax[1,1].scatter(intc_diff.loc['2019-01-01':'2019-09-15'].index,intc_diff.loc['2019-01-01':'2019-09-15']['diff'],color='r')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

# %%
#for moving windows  here we can check statactics of perticuler time period and then slide the windows accross the dtata by specified the time interval that way statsatic continualyy calculated  as long as the window fall first within the dates of the time series
#the rolling means smoothen  out short-term fluctuatuion and highlight the data

# %%
#daily percentasges 
daily_close_ibm=ibm[['Adj Close']]

#Daily returns
daily_pct_change_ibm=daily_close_ibm.pct_change()

#replace NA value with 0
daily_pct_change_ibm.fillna(0,inplace=True)

daily_pct_change_ibm.head()
# Out:
#             Adj Close
# Date
# 2004-01-02   0.000000
# 2004-01-05   0.016385
# 2004-01-06   0.000107
# 2004-01-07  -0.003009
# 2004-01-08   0.002802

# %%
daily_pct_change_ibm.hist(bins=50)
plt.show()

# %%
import seaborn as sns
sns.set()


daily_close_amd=amd[['Adj Close']]
daily_pct_change_amd=daily_close_amd.pct_change()
daily_pct_change_amd.fillna(0,inplace=True)

daily_close_intc=intc[['Adj Close']]
daily_pct_change_intc=daily_close_intc.pct_change()
daily_pct_change_intc.fillna(0,inplace=True)

daily_close_qcom=qcom[['Adj Close']]
daily_pct_change_qcom=daily_close_qcom.pct_change()
daily_pct_change_qcom.fillna(0,inplace=True)

daily_close_nvda=nvda[['Adj Close']]
daily_pct_change_nvda=daily_close_nvda.pct_change()
daily_pct_change_nvda.fillna(0,inplace=True)


#f,ax=plt.scatter(2,2,figsize=(10,10),sharex=True)


f,ax=plt.subplots(2,2,figsize=(12,7))
#sharex=True,sharey=True

sns.distplot(daily_pct_change_nvda['Adj Close'],color="b",ax=ax[0,0],axlabel="nvda")

sns.distplot(daily_pct_change_intc['Adj Close'],color="y",ax=ax[0,1],axlabel="intc")

sns.distplot(daily_pct_change_qcom['Adj Close'],color="g",ax=ax[1,1],axlabel="qcom")

sns.distplot(daily_pct_change_amd['Adj Close'],color="r",ax=ax[1,0],axlabel="amd")

# %%
#volaitality

# %%
import numpy as np
min_periods=75

#calculate the volatility
vol=daily_pct_change_ibm.rolling(min_periods).std()*np.sqrt(min_periods)
vol.fillna(0,inplace=True)
vol.tail()
# Out:
#             Adj Close
# Date
# 2019-09-10   0.125065
# 2019-09-11   0.125571
# 2019-09-12   0.124641
# 2019-09-13   0.124419
# 2019-09-16   0.124789

# %%
#plote the volatility
vol.plot(figsize=(10,8))

#show the plot

plt.show()

# %%
#com1
ibm_adj_close_px=ibm['Adj Close']
#short moving window rolling mean
ibm['42']=ibm_adj_close_px.rolling(window=40).mean()
#long moving window rolling mean
ibm['252']=ibm_adj_close_px.rolling(window=252).mean()
#plot the adjust closing price ,#short and long moving window rolling mean
ibm[['Adj Close','42','252']].plot(title="ibm")
#show plot
plt.show()

#com2
nvda_adj_close_px=nvda['Adj Close']
#short moving window rolling mean
nvda['42']=nvda_adj_close_px.rolling(window=40).mean()
#long moving window rolling mean
nvda['252']=nvda_adj_close_px.rolling(window=252).mean()
#plot the adjust closing price ,#short and long moving window rolling mean
nvda[['Adj Close','42','252']].plot(title="ibm")
#show plot
plt.show()

#com3
qcom_adj_close_px=qcom['Adj Close']
#short moving window rolling mean
qcom['42']=qcom_adj_close_px.rolling(window=40).mean()
#long moving window rolling mean
qcom['252']=qcom_adj_close_px.rolling(window=252).mean()
#plot the adjust closing price ,#short and long moving window rolling mean
qcom[['Adj Close','42','252']].plot(title="ibm")
#show plot
plt.show()

#com4
intc_adj_close_px=intc['Adj Close']
#short moving window rolling mean
intc['42']=intc_adj_close_px.rolling(window=40).mean()
#long moving window rolling mean
intc['252']=intc_adj_close_px.rolling(window=252).mean()
#plot the adjust closing price ,#short and long moving window rolling mean
intc[['Adj Close','42','252']].plot(title="ibm")
#show plot
plt.show()

# %%
ibm.loc['2019-01-01':'2019-09-15'][['Adj Close','42','252']].plot(title="IBM in 2019");
nvda.loc['2019-01-01':'2019-09-15'][['Adj Close','42','252']].plot(title="nvda in 2019");
